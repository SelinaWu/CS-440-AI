# %%
The goal of this assignment is to implement A* search that will find two different factory sequences:

    1. find the factory sequence with the smallest number of stops (the smallest number of factories visited).
    2. find the factory sequence with the smallest number of miles traveled.

Solve this problem using A* search. Your report should specify your state representation, actions, and your heuristic. 
The heuristic need not be very smart, but it needs to be non-zero, and it needs to be admissible and consistent.

# %%
# W0, W1, W2, W3, W4
W =[ ['A', 'E', 'D', 'C', 'A'],
     ['B', 'E', 'A', 'C', 'D'],
     ['B', 'A', 'B', 'C', 'E'],
     ['D', 'A', 'D', 'B', 'D'],
     ['B', 'E', 'C', 'B', 'D'] ]

# pt_sample = [W#, # widget, (pt1, pt2, pt3, pt4, pt5), steps]
pt_sample = [0, 2, [2, 2, 2, 2, 2], 4]
# heuristic for smallest stops
def heuristic(pt):
    distance = [0, 0, 0, 0, 0]
    for i in range(5):
        curr = pt[2][i]
        temp = [0, 0, 0, 0, 0]
        if i == pt[0]:
            curr += 1 
        while curr != len(W[i]):
            if(W[i][curr] == 'A'):
                temp[0] += 1
            elif(W[i][curr] == 'B'):
                temp[1] += 1
            elif(W[i][curr] == 'C'):
                temp[2] += 1
            elif(W[i][curr] == 'D'):
                temp[3] += 1
            elif(W[i][curr] == 'E'):
                temp[4] += 1
            curr += 1 
        for a in range(len(temp)):
            if(distance[a] < temp[a]):
                distance[a] = temp[a]
    return sum(distance) + pt[-1]
print(heuristic(pt_sample))
# Out:
# 10

# %%
# s = [0,[-1, -1, (0, 0, 0, 0, 0), step]]
import heapq
import copy

def A_star(W):
    curr_char = {}
    loc = [0, 0, 0, 0, 0]
    heap = []
    # initialize points
    for i in range(5):
        if curr_char.get(W[i][0]) == None:
            curr_char[W[i][0]] = 1
            temp_pt = [i, 0, loc, 1]
            temp_h = heuristic(temp_pt)
            heapq.heappush(heap, [temp_h, temp_pt,W[i][0]])
    # start search
    while heap:
        curr_char.clear() # clear the dictionary
        curr_pt = heapq.heappop(heap)
        print(curr_pt)
        curr_loc = copy.deepcopy(curr_pt[1][2])
        curr_w = W[curr_pt[1][0]][curr_pt[1][1]]
        # update new location
        for i in range(5):
            if curr_loc[i] < len(W[i]):
                if W[i][curr_loc[i]] == curr_w:
                    curr_loc[i] += 1
        if sum(curr_loc) == 25:
            break
        # push all new points
        for i in range(5):
            if curr_loc[i] < len(W[i]):
                if curr_char.get(W[i][curr_loc[i]]) == None:
                    curr_char[W[i][curr_loc[i]]] = 1
                    temp_pt = [i, curr_loc[i], curr_loc, curr_pt[1][3] + 1]# add one to the original step
                    temp_h = heuristic(temp_pt)
                    heapq.heappush(heap, [temp_h, temp_pt,curr_pt[2] + W[i][curr_loc[i]]])

# %%
import heapq
import copy
#     A    B    C     D    E
D = [[0, 1064, 673, 1401, 277],
     [1064, 0, 958, 1934, 337],
     [673, 958, 0, 1001, 399],
     [1401, 1934, 1001, 0, 387],
     [277, 337, 399, 387, 0]]


# The credits for this code go to UIUC_CS440_FALL18_HW01 by Zhenwei Wu, Yuji Chai, Zhoushi Zhu 
# uptree
def addelement_dset(dset, num):
    for i in range(num):
        dset.append(-1)

def find_dset(dset, elem):
    if(dset[elem] < 0):
        return elem
    else:
        find_result = find_dset(dset,dset[elem])
        dset[elem] = find_result
        return find_result

def setunion_dset(dset, a, b):
    root1 = find_dset(dset,a)
    root2 = find_dset(dset,b)
    
    newsize = dset[root1] + dset[root2]
    if(dset[root1] >= dset[root2]):
        dset[root2] = root1
        dset[root1] = newsize
    else:
        dset[root1] = root2
        dset[root2] = newsize
# generate distance = [1401, 'D2', 'A4']       
def hForAll(ls):
    distance_list = []
    for i in range(len(ls)):
        for j in range(i+1, len(ls)):
            if ls[i][0] != ls[j][0]:
                temp_distance = D[ord(ls[i][0])-65][ord(ls[j][0])-65]
                distance_list.append([temp_distance, [ls[i][0], str(ls[i][1])],[ls[j][0], str(ls[j][1])]])
    return distance_list

# Krusal
def mst(ls):
    dset = []
    Edge = hForAll(ls)
    E_heap = []
    distance_dic = {}
    addelement_dset(dset, len(ls))
    ct = 0
    for elm in Edge:
        heapq.heappush(E_heap, elm)
        if distance_dic.get(elm[1][0] + elm[1][1]) == None:
            distance_dic[elm[1][0] + elm[1][1]] = ct
            ct += 1
        if distance_dic.get(elm[2][0] + elm[2][1]) == None:
            distance_dic[elm[2][0] + elm[2][1]] = ct
            ct += 1
    edge_count = 0
    total_dist = 0

    while E_heap:
        if edge_count == len(ls):
            break
        it = heapq.heappop(E_heap)
        A = distance_dic[it[1][0] + it[1][1]]
        B = distance_dic[it[2][0] + it[2][1]]
        for it in Edge:
            if find_dset(dset,A) != find_dset(dset,B):
                # print("a: ",A," b: ",B)
                total_dist += it[0]
                setunion_dset(dset,A, B)
    return total_dist
##########################################################################    
sample = [0, 2, [2, 2, 2, 2, 2], 4]

def h_distance(pt):
    char_dic = {}
    w_ls = []
    for i in range(5):
        curr = pt[2][i]
        while curr != len(W[i]):
            if char_dic.get(W[i][curr] + str(curr)) == None:
                char_dic[W[i][curr] + str(curr)] = 1
                w_ls.append([W[i][curr],curr])
            curr += 1 
    return mst(w_ls) + pt[-1]

#print(h_distance(sample))

# %%
# s = [0,[-1, -1, [0, 0, 0, 0, 0], step]]
import heapq
import copy

def A_star_D(W):
    curr_char = {}
    loc = [0, 0, 0, 0, 0]
    heap = []
    # initialize points
    for i in range(5):
        if curr_char.get(W[i][0]) == None:
            curr_char[W[i][0]] = 1
            temp_pt = [i, 0, loc, 0]
            temp_h = h_distance(temp_pt)
            heapq.heappush(heap, [temp_h, temp_pt,W[i][0]])
    # start search
    while heap:
        curr_char.clear() # clear the dictionary
        curr_pt = heapq.heappop(heap)
        curr_loc = copy.deepcopy(curr_pt[1][2])
        curr_w = W[curr_pt[1][0]][curr_pt[1][1]]
        print(curr_pt)
        # update new location
        for i in range(5):
            if curr_loc[i] < len(W[i]):
                if W[i][curr_loc[i]] == curr_w:
                    curr_loc[i] += 1
        if sum(curr_loc) == 25:
            print("Final: ",curr_pt)
            break
        # push all new points
        for i in range(5):
            if curr_loc[i] < len(W[i]):
                if curr_char.get(W[i][curr_loc[i]]) == None:
                    curr_char[W[i][curr_loc[i]]] = 1
                    temp_pt = [i, curr_loc[i], curr_loc, curr_pt[1][3] + 
                               D[ord(curr_w)-65][ord(W[i][curr_loc[i]])-65]]# add new distance to the original step
                    temp_h = h_distance(temp_pt)
                    heapq.heappush(heap, [temp_h, temp_pt,curr_pt[2] + W[i][curr_loc[i]]])

# %%
A_star(W)
# Out:
# [9, [0, 0, [0, 0, 0, 0, 0], 1], 'A']
# [9, [3, 0, [0, 0, 0, 0, 0], 1], 'D']
# [9, [0, 0, [0, 0, 0, 1, 0], 2], 'DA']
# [9, [3, 0, [1, 0, 0, 0, 0], 2], 'AD']
# [9, [3, 2, [1, 0, 0, 2, 0], 3], 'DAD']
# [10, [0, 1, [1, 0, 0, 0, 0], 2], 'AE']
# [10, [0, 1, [1, 0, 0, 1, 0], 3], 'ADE']
# [10, [0, 1, [1, 0, 0, 2, 0], 3], 'DAE']
# [10, [0, 1, [1, 0, 0, 3, 0], 4], 'DADE']
# [10, [1, 0, [0, 0, 0, 0, 0], 1], 'B']
# [9, [0, 0, [0, 1, 1, 0, 1], 2], 'BA']
# [9, [3, 0, [0, 1, 1, 0, 1], 2], 'BD']
# [9, [0, 0, [0, 1, 1, 1, 1], 3], 'BDA']
# [9, [3, 0, [1, 1, 2, 0, 1], 3], 'BAD']
# [9, [3, 2, [1, 1, 2, 2, 1], 4], 'BDAD']
# [10, [0, 1, [1, 1, 2, 0, 1], 3], 'BAE']
# [10, [0, 1, [1, 1, 2, 1, 1], 4], 'BADE']
# [10, [0, 1, [1, 1, 2, 2, 1], 4], 'BDAE']
# [10, [0, 1, [1, 1, 2, 3, 1], 5], 'BDADE']
# [10, [1, 0, [0, 0, 0, 1, 0], 2], 'DB']
# [9, [0, 0, [0, 1, 1, 1, 1], 3], 'DBA']
# [9, [3, 2, [1, 1, 2, 2, 1], 4], 'DBAD']
# [10, [0, 1, [1, 1, 2, 2, 1], 4], 'DBAE']
# [10, [0, 1, [1, 1, 2, 3, 1], 5], 'DBADE']
# [10, [1, 0, [1, 0, 0, 0, 0], 2], 'AB']
# [9, [3, 0, [1, 1, 1, 0, 1], 3], 'ABD']
# [10, [0, 1, [1, 1, 1, 0, 1], 3], 'ABE']
# [10, [0, 1, [1, 1, 1, 1, 1], 4], 'ABDE']
# [10, [1, 0, [1, 0, 0, 1, 0], 3], 'ADB']
# [10, [0, 1, [1, 1, 1, 1, 1], 4], 'ADBE']
# [10, [1, 0, [1, 0, 0, 2, 0], 3], 'DAB']
# [9, [3, 2, [1, 1, 1, 2, 1], 4], 'DABD']
# [10, [0, 1, [1, 1, 1, 2, 1], 4], 'DABE']
# [10, [0, 1, [1, 1, 1, 3, 1], 5], 'DABDE']
# [10, [1, 0, [1, 0, 0, 3, 0], 4], 'DADB']
# [10, [0, 1, [1, 1, 1, 4, 1], 5], 'DADBE']
# [10, [1, 1, [0, 1, 1, 0, 1], 2], 'BE']
# [10, [0, 0, [0, 2, 1, 0, 2], 3], 'BEA']
# [10, [1, 1, [0, 1, 1, 1, 1], 3], 'BDE']
# [10, [0, 0, [0, 2, 1, 1, 2], 4], 'BDEA']
# [10, [1, 1, [0, 1, 1, 1, 1], 3], 'DBE']
# [10, [0, 0, [0, 2, 1, 1, 2], 4], 'DBEA']
# [10, [2, 1, [1, 1, 1, 0, 1], 3], 'ABA']
# [10, [2, 1, [1, 1, 1, 1, 1], 4], 'ABDA']
# [10, [2, 1, [1, 1, 1, 1, 1], 4], 'ADBA']
# [10, [2, 1, [1, 1, 1, 2, 1], 4], 'DABA']
# [10, [2, 1, [1, 1, 1, 3, 1], 5], 'DABDA']
# [10, [2, 1, [1, 1, 1, 4, 1], 5], 'DADBA']
# [10, [2, 2, [1, 1, 2, 0, 1], 3], 'BAB']
# [10, [2, 2, [1, 1, 2, 1, 1], 4], 'BADB']
# [10, [2, 2, [1, 1, 2, 2, 1], 4], 'BDAB']
# [10, [2, 2, [1, 1, 2, 2, 1], 4], 'DBAB']
# [10, [2, 2, [1, 1, 2, 3, 1], 5], 'BDADB']
# [10, [2, 2, [1, 1, 2, 3, 1], 5], 'DBADB']
# [10, [3, 0, [0, 2, 1, 0, 2], 3], 'BED']
# [10, [0, 0, [0, 2, 1, 1, 2], 4], 'BEDA']
# [10, [3, 0, [1, 1, 2, 0, 1], 4], 'ABAD']
# [10, [3, 0, [1, 1, 3, 0, 1], 4], 'BABD']
# [10, [3, 0, [1, 3, 2, 0, 2], 4], 'BEAD']
# [10, [3, 1, [1, 0, 0, 1, 0], 3], 'ADA']
# [10, [3, 1, [1, 1, 2, 1, 1], 4], 'BADA']
# [10, [3, 2, [1, 0, 0, 2, 0], 4], 'ADAD']
# [10, [3, 2, [1, 1, 2, 2, 1], 5], 'ABDAD']
# [10, [3, 2, [1, 1, 2, 2, 1], 5], 'ADBAD']
# [10, [3, 2, [1, 1, 2, 2, 1], 5], 'BADAD']
# [10, [3, 2, [1, 1, 2, 2, 1], 5], 'DABAD']
# [10, [3, 2, [1, 1, 3, 2, 1], 5], 'BDABD']
# [10, [3, 2, [1, 1, 3, 2, 1], 5], 'DBABD']
# [10, [3, 2, [1, 3, 2, 2, 2], 5], 'BDEAD']
# [10, [3, 2, [1, 3, 2, 2, 2], 5], 'BEDAD']
# [10, [3, 2, [1, 3, 2, 2, 2], 5], 'DBEAD']
# [10, [3, 3, [1, 1, 1, 3, 1], 5], 'DABDB']
# [10, [3, 4, [1, 1, 1, 4, 1], 5], 'DADBD']
# [11, [0, 1, [1, 0, 0, 2, 0], 4], 'ADAE']
# [11, [0, 1, [1, 0, 0, 3, 0], 5], 'ADADE']
# [11, [0, 1, [1, 1, 1, 4, 1], 6], 'DABDBE']
# [11, [0, 1, [1, 1, 1, 5, 1], 6], 'DADBDE']
# [11, [0, 1, [1, 1, 2, 0, 1], 4], 'ABAE']
# [11, [0, 1, [1, 1, 2, 1, 1], 5], 'ABADE']
# [11, [0, 1, [1, 1, 2, 2, 1], 5], 'ABDAE']
# [11, [0, 1, [1, 1, 2, 2, 1], 5], 'ADBAE']
# [11, [0, 1, [1, 1, 2, 2, 1], 5], 'BADAE']
# [11, [0, 1, [1, 1, 2, 2, 1], 5], 'DABAE']
# [11, [0, 1, [1, 1, 2, 3, 1], 6], 'ABDADE']
# [11, [0, 1, [1, 1, 2, 3, 1], 6], 'ADBADE']
# [11, [0, 1, [1, 1, 2, 3, 1], 6], 'BADADE']
# [11, [0, 1, [1, 1, 2, 3, 1], 6], 'DABADE']
# [11, [0, 1, [1, 1, 2, 3, 1], 6], 'DABDAE']
# [11, [0, 1, [1, 1, 2, 4, 1], 6], 'DADBAE']
# [11, [0, 1, [1, 1, 3, 0, 1], 4], 'BABE']
# [11, [0, 1, [1, 1, 3, 1, 1], 5], 'BABDE']
# [11, [0, 1, [1, 1, 3, 1, 1], 5], 'BADBE']
# [11, [0, 1, [1, 1, 3, 2, 1], 5], 'BDABE']
# [11, [0, 1, [1, 1, 3, 2, 1], 5], 'DBABE']
# [11, [0, 1, [1, 1, 3, 3, 1], 6], 'BDABDE']
# [11, [0, 1, [1, 1, 3, 3, 1], 6], 'DBABDE']
# [11, [0, 1, [1, 1, 3, 4, 1], 6], 'BDADBE']
# [11, [0, 1, [1, 1, 3, 4, 1], 6], 'DBADBE']
# [11, [0, 1, [1, 3, 2, 0, 2], 4], 'BEAE']
# [11, [0, 1, [1, 3, 2, 1, 2], 5], 'BEADE']
# [11, [0, 1, [1, 3, 2, 2, 2], 5], 'BDEAE']
# [11, [0, 1, [1, 3, 2, 2, 2], 5], 'BEDAE']
# [11, [0, 1, [1, 3, 2, 2, 2], 5], 'DBEAE']
# [11, [0, 1, [1, 3, 2, 3, 2], 6], 'BDEADE']
# [11, [0, 1, [1, 3, 2, 3, 2], 6], 'BEDADE']
# [11, [0, 1, [1, 3, 2, 3, 2], 6], 'DBEADE']
# [11, [0, 2, [2, 0, 0, 0, 0], 3], 'AED']
# [11, [0, 2, [2, 0, 0, 1, 0], 4], 'ADED']
# [11, [0, 2, [2, 0, 0, 2, 0], 4], 'DAED']
# [11, [0, 2, [2, 0, 0, 3, 0], 5], 'DADED']
# [11, [0, 2, [2, 2, 1, 0, 2], 4], 'ABED']
# [11, [0, 2, [2, 2, 1, 1, 2], 5], 'ABDED']
# [11, [0, 2, [2, 2, 1, 1, 2], 5], 'ADBED']
# [11, [0, 2, [2, 2, 1, 2, 2], 5], 'DABED']
# [11, [0, 2, [2, 2, 1, 3, 2], 6], 'DABDED']
# [11, [0, 2, [2, 2, 1, 4, 2], 6], 'DADBED']
# [11, [0, 2, [2, 2, 2, 0, 2], 4], 'BAED']
# [11, [0, 2, [2, 2, 2, 1, 2], 5], 'BADED']
# [11, [0, 2, [2, 2, 2, 2, 2], 5], 'BDAED']
# [11, [0, 2, [2, 2, 2, 2, 2], 5], 'DBAED']
# [11, [0, 2, [2, 2, 2, 3, 2], 6], 'BDADED']
# [11, [0, 2, [2, 2, 2, 3, 2], 6], 'DBADED']
# [11, [0, 3, [3, 0, 0, 1, 0], 4], 'AEDC']
# [11, [0, 3, [3, 0, 0, 3, 0], 5], 'DAEDC']
# [11, [0, 3, [3, 2, 1, 1, 2], 5], 'ABEDC']
# [11, [0, 3, [3, 2, 1, 3, 2], 6], 'DABEDC']
# [11, [0, 3, [3, 2, 2, 1, 2], 5], 'BAEDC']
# [11, [0, 3, [3, 2, 2, 3, 2], 6], 'BDAEDC']
# [11, [0, 3, [3, 2, 2, 3, 2], 6], 'DBAEDC']
# [11, [1, 0, [1, 0, 0, 2, 0], 4], 'ADAB']
# [10, [3, 2, [1, 1, 1, 2, 1], 5], 'ADABD']
# [11, [0, 1, [1, 1, 1, 2, 1], 5], 'ADABE']
# [11, [0, 1, [1, 1, 1, 3, 1], 6], 'ADABDE']
# [11, [1, 0, [1, 0, 0, 3, 0], 5], 'ADADB']
# [11, [0, 1, [1, 1, 1, 4, 1], 6], 'ADADBE']
# [11, [1, 0, [2, 0, 0, 0, 0], 3], 'AEB']
# [11, [0, 2, [2, 1, 1, 0, 1], 4], 'AEBD']
# [11, [0, 3, [3, 1, 1, 1, 1], 5], 'AEBDC']
# [11, [1, 0, [2, 0, 0, 1, 0], 4], 'ADEB']
# [11, [0, 2, [2, 1, 1, 1, 1], 5], 'ADEBD']
# [11, [1, 0, [2, 0, 0, 2, 0], 4], 'DAEB']
# [11, [0, 2, [2, 1, 1, 2, 1], 5], 'DAEBD']
# [11, [0, 3, [3, 1, 1, 3, 1], 6], 'DAEBDC']
# [11, [1, 0, [2, 0, 0, 3, 0], 5], 'DADEB']
# [11, [0, 2, [2, 1, 1, 4, 1], 6], 'DADEBD']
# [11, [1, 0, [3, 0, 0, 1, 0], 4], 'AEDB']
# [11, [0, 3, [3, 1, 1, 1, 1], 5], 'AEDBC']
# [11, [1, 0, [3, 0, 0, 3, 0], 5], 'DAEDB']
# [11, [0, 3, [3, 1, 1, 4, 1], 6], 'DAEDBC']
# [11, [1, 1, [2, 1, 1, 0, 1], 4], 'AEBE']
# [11, [1, 1, [2, 1, 1, 1, 1], 5], 'ADEBE']
# [11, [1, 1, [2, 1, 1, 2, 1], 5], 'DAEBE']
# [11, [1, 1, [2, 1, 1, 4, 1], 6], 'DADEBE']
# [11, [1, 1, [3, 1, 1, 1, 1], 5], 'AEBDE']
# [11, [1, 1, [3, 1, 1, 1, 1], 5], 'AEDBE']
# [11, [1, 1, [3, 1, 1, 3, 1], 6], 'DAEBDE']
# [11, [1, 1, [3, 1, 1, 4, 1], 6], 'DAEDBE']
# [11, [1, 2, [2, 2, 1, 0, 2], 4], 'ABEA']
# [11, [1, 2, [2, 2, 1, 1, 2], 5], 'ABDEA']
# [11, [1, 2, [2, 2, 1, 1, 2], 5], 'ADBEA']
# [11, [1, 2, [2, 2, 1, 2, 2], 5], 'DABEA']
# [11, [1, 2, [2, 2, 1, 3, 2], 6], 'DABDEA']
# [11, [1, 2, [2, 2, 1, 4, 2], 6], 'DADBEA']
# [11, [1, 2, [2, 2, 2, 0, 2], 4], 'BAEA']
# [11, [1, 2, [2, 2, 2, 1, 2], 5], 'BADEA']
# [11, [1, 2, [2, 2, 2, 2, 2], 5], 'BDAEA']
# [11, [1, 2, [2, 2, 2, 2, 2], 5], 'DBAEA']
# [11, [1, 2, [2, 2, 2, 3, 2], 6], 'BDADEA']
# [11, [1, 2, [2, 2, 2, 3, 2], 6], 'DBADEA']
# [11, [1, 2, [3, 2, 1, 1, 2], 5], 'ABEDA']
# [11, [1, 2, [3, 2, 1, 3, 2], 6], 'DABEDA']
# [11, [1, 2, [3, 2, 2, 1, 2], 5], 'BAEDA']
# [11, [1, 2, [3, 2, 2, 3, 2], 6], 'BDAEDA']
# [11, [1, 2, [3, 2, 2, 3, 2], 6], 'DBAEDA']
# [11, [1, 3, [1, 3, 2, 0, 2], 4], 'BEAC']
# [11, [1, 3, [1, 3, 2, 1, 2], 5], 'BEADC']
# [11, [1, 3, [1, 3, 2, 2, 2], 5], 'BDEAC']
# [11, [1, 3, [1, 3, 2, 2, 2], 5], 'BEDAC']
# [11, [1, 3, [1, 3, 2, 2, 2], 5], 'DBEAC']
# [11, [1, 3, [1, 3, 2, 3, 2], 6], 'BDEADC']
# [11, [1, 3, [1, 3, 2, 3, 2], 6], 'BEDADC']
# [11, [1, 3, [1, 3, 2, 3, 2], 6], 'DBEADC']
# [11, [2, 1, [1, 1, 1, 2, 1], 5], 'ADABA']
# [11, [2, 1, [1, 1, 1, 3, 1], 6], 'ADABDA']
# [11, [2, 1, [1, 1, 1, 4, 1], 6], 'ADADBA']
# [11, [2, 1, [1, 1, 1, 4, 1], 6], 'DABDBA']
# [11, [2, 1, [1, 1, 1, 5, 1], 6], 'DADBDA']
# [11, [2, 1, [2, 1, 1, 0, 1], 4], 'AEBA']
# [11, [2, 1, [2, 1, 1, 1, 1], 5], 'ADEBA']
# [11, [2, 1, [2, 1, 1, 2, 1], 5], 'DAEBA']
# [11, [2, 1, [2, 1, 1, 4, 1], 6], 'DADEBA']
# [11, [2, 1, [3, 1, 1, 1, 1], 5], 'AEBDA']
# [11, [2, 1, [3, 1, 1, 1, 1], 5], 'AEDBA']
# [11, [2, 1, [3, 1, 1, 3, 1], 6], 'DAEBDA']
# [11, [2, 1, [3, 1, 1, 4, 1], 6], 'DAEDBA']
# [11, [2, 2, [1, 1, 2, 0, 1], 4], 'ABAB']
# [11, [2, 2, [1, 1, 2, 1, 1], 5], 'ABADB']
# [11, [2, 2, [1, 1, 2, 2, 1], 5], 'ABDAB']
# [11, [2, 2, [1, 1, 2, 2, 1], 5], 'ADBAB']
# [11, [2, 2, [1, 1, 2, 2, 1], 5], 'BADAB']
# [11, [2, 2, [1, 1, 2, 2, 1], 5], 'DABAB']
# [11, [2, 2, [1, 1, 2, 3, 1], 6], 'ABDADB']
# [11, [2, 2, [1, 1, 2, 3, 1], 6], 'ADBADB']
# [11, [2, 2, [1, 1, 2, 3, 1], 6], 'BADADB']
# [11, [2, 2, [1, 1, 2, 3, 1], 6], 'DABADB']
# [11, [2, 2, [1, 1, 2, 3, 1], 6], 'DABDAB']
# [11, [2, 2, [1, 1, 2, 4, 1], 6], 'DADBAB']
# [11, [2, 2, [1, 3, 2, 0, 2], 4], 'BEAB']
# [11, [2, 2, [1, 3, 2, 1, 2], 5], 'BEADB']
# [11, [2, 2, [1, 3, 2, 2, 2], 5], 'BDEAB']
# [11, [2, 2, [1, 3, 2, 2, 2], 5], 'BEDAB']
# [11, [2, 2, [1, 3, 2, 2, 2], 5], 'DBEAB']
# [11, [2, 2, [1, 3, 2, 3, 2], 6], 'BDEADB']
# [11, [2, 2, [1, 3, 2, 3, 2], 6], 'BEDADB']
# [11, [2, 2, [1, 3, 2, 3, 2], 6], 'DBEADB']
# [11, [2, 2, [2, 2, 2, 0, 2], 4], 'BAEB']
# [11, [2, 2, [2, 2, 2, 1, 2], 5], 'BADEB']
# [11, [2, 2, [2, 2, 2, 2, 2], 5], 'BDAEB']
# [11, [2, 2, [2, 2, 2, 2, 2], 5], 'DBAEB']
# [11, [2, 2, [2, 2, 2, 3, 2], 6], 'BDADEB']
# [11, [2, 2, [2, 2, 2, 3, 2], 6], 'DBADEB']
# [11, [2, 2, [3, 2, 2, 1, 2], 5], 'BAEDB']
# [11, [2, 2, [3, 2, 2, 3, 2], 6], 'BDAEDB']
# [11, [2, 2, [3, 2, 2, 3, 2], 6], 'DBAEDB']
# [11, [2, 3, [1, 1, 3, 0, 1], 4], 'BABC']
# [11, [2, 3, [1, 1, 3, 1, 1], 5], 'BABDC']
# [11, [2, 3, [1, 1, 3, 1, 1], 5], 'BADBC']
# [11, [2, 3, [1, 1, 3, 2, 1], 5], 'BDABC']
# [11, [2, 3, [1, 1, 3, 2, 1], 5], 'DBABC']
# [11, [2, 3, [1, 1, 3, 3, 1], 6], 'BDABDC']
# [11, [2, 3, [1, 1, 3, 3, 1], 6], 'DBABDC']
# [11, [2, 3, [1, 1, 3, 4, 1], 6], 'BDADBC']
# [11, [2, 3, [1, 1, 3, 4, 1], 6], 'DBADBC']
# [11, [3, 0, [1, 1, 3, 0, 1], 5], 'ABABD']
# [11, [3, 0, [1, 1, 4, 0, 1], 5], 'BABCD']
# [11, [3, 0, [1, 3, 3, 0, 2], 5], 'BEABD']
# [11, [3, 1, [1, 1, 2, 1, 1], 5], 'ABADA']
# [11, [3, 1, [1, 1, 3, 1, 1], 5], 'BABDA']
# [11, [3, 1, [1, 1, 3, 1, 1], 5], 'BADBA']
# [11, [3, 1, [1, 3, 2, 1, 2], 5], 'BEADA']
# [11, [3, 1, [2, 0, 0, 1, 0], 4], 'ADEA']
# [11, [3, 1, [3, 0, 0, 1, 0], 4], 'AEDA']
# [11, [3, 2, [1, 1, 2, 2, 1], 6], 'ABADAD']
# [11, [3, 2, [1, 1, 2, 2, 1], 6], 'ADABAD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'ABDABD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'ADBABD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'BABDAD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'BADABD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'BADBAD']
# [11, [3, 2, [1, 1, 3, 2, 1], 6], 'DABABD']
# [11, [3, 2, [1, 1, 4, 2, 1], 6], 'BDABCD']
# [11, [3, 2, [1, 1, 4, 2, 1], 6], 'DBABCD']
# [11, [3, 2, [1, 3, 2, 2, 2], 6], 'BEADAD']
# [11, [3, 2, [1, 3, 3, 2, 2], 6], 'BDEABD']
# [11, [3, 2, [1, 3, 3, 2, 2], 6], 'BEDABD']
# [11, [3, 2, [1, 3, 3, 2, 2], 6], 'DBEABD']
# [11, [3, 2, [3, 0, 0, 2, 0], 5], 'AEDAD']
# [11, [3, 2, [3, 1, 2, 2, 1], 6], 'AEBDAD']
# [11, [3, 2, [3, 1, 2, 2, 1], 6], 'AEDBAD']
# [11, [3, 2, [3, 3, 2, 2, 2], 6], 'ABEDAD']
# [11, [3, 2, [3, 3, 2, 2, 2], 6], 'BAEDAD']
# [11, [3, 3, [1, 1, 1, 3, 1], 6], 'ADABDB']
# [11, [3, 3, [1, 1, 3, 3, 1], 6], 'BDABDB']
# [11, [3, 3, [1, 1, 3, 3, 1], 6], 'DBABDB']
# [11, [3, 3, [2, 2, 1, 3, 2], 6], 'DABDEB']
# [11, [3, 3, [3, 1, 1, 3, 1], 6], 'DAEBDB']
# [11, [3, 3, [3, 2, 1, 3, 2], 6], 'DABEDB']
# [11, [3, 4, [1, 1, 1, 4, 1], 6], 'ADADBD']
# [11, [3, 4, [1, 1, 1, 4, 1], 6], 'DABDBD']
# [11, [3, 4, [1, 1, 2, 4, 1], 6], 'DADBAD']
# [11, [3, 4, [1, 1, 3, 4, 1], 6], 'BDADBD']
# [11, [3, 4, [1, 1, 3, 4, 1], 6], 'DBADBD']
# [11, [3, 4, [3, 1, 1, 4, 1], 6], 'DAEDBD']
# [11, [4, 2, [0, 2, 1, 0, 2], 3], 'BEC']
# [11, [0, 0, [0, 2, 1, 0, 3], 4], 'BECA']
# [11, [3, 0, [0, 2, 1, 0, 3], 4], 'BECD']
# [11, [0, 0, [0, 2, 1, 1, 3], 5], 'BECDA']
# [11, [3, 0, [1, 3, 2, 0, 3], 5], 'BECAD']
# [11, [3, 2, [1, 3, 2, 2, 3], 6], 'BECDAD']
# [11, [4, 2, [0, 2, 1, 1, 2], 4], 'BDEC']
# [11, [0, 0, [0, 2, 1, 1, 3], 5], 'BDECA']
# [11, [3, 2, [1, 3, 2, 2, 3], 6], 'BDECAD']
# [11, [4, 2, [0, 2, 1, 1, 2], 4], 'BEDC']
# [11, [0, 0, [0, 2, 1, 1, 3], 5], 'BEDCA']
# [11, [3, 2, [1, 3, 2, 2, 3], 6], 'BEDCAD']
# [11, [4, 2, [0, 2, 1, 1, 2], 4], 'DBEC']
# [11, [0, 0, [0, 2, 1, 1, 3], 5], 'DBECA']
# [11, [3, 2, [1, 3, 2, 2, 3], 6], 'DBECAD']
# [11, [4, 2, [2, 2, 1, 0, 2], 4], 'ABEC']
# [11, [4, 2, [2, 2, 1, 1, 2], 5], 'ABDEC']
# [11, [4, 2, [2, 2, 1, 1, 2], 5], 'ADBEC']
# [11, [4, 2, [2, 2, 1, 2, 2], 5], 'DABEC']
# [11, [4, 2, [2, 2, 1, 3, 2], 6], 'DABDEC']
# [11, [4, 2, [2, 2, 1, 4, 2], 6], 'DADBEC']
# [11, [4, 2, [2, 2, 2, 0, 2], 4], 'BAEC']
# [11, [4, 2, [2, 2, 2, 1, 2], 5], 'BADEC']
# [11, [4, 2, [2, 2, 2, 2, 2], 5], 'BDAEC']
# [11, [4, 2, [2, 2, 2, 2, 2], 5], 'DBAEC']
# [11, [4, 2, [2, 2, 2, 3, 2], 6], 'BDADEC']
# [11, [4, 2, [2, 2, 2, 3, 2], 6], 'DBADEC']
# [12, [0, 1, [1, 1, 1, 4, 1], 7], 'ADABDBE']
# [12, [0, 1, [1, 1, 1, 5, 1], 7], 'ADADBDE']
# [12, [0, 1, [1, 1, 1, 5, 1], 7], 'DABDBDE']
# [12, [0, 1, [1, 1, 2, 2, 1], 6], 'ABADAE']
# [12, [0, 1, [1, 1, 2, 2, 1], 6], 'ADABAE']
# [12, [0, 1, [1, 1, 2, 3, 1], 7], 'ABADADE']
# [12, [0, 1, [1, 1, 2, 3, 1], 7], 'ADABADE']
# [12, [0, 1, [1, 1, 2, 3, 1], 7], 'ADABDAE']
# [12, [0, 1, [1, 1, 2, 4, 1], 7], 'ADADBAE']
# [12, [0, 1, [1, 1, 2, 4, 1], 7], 'DABDBAE']
# [12, [0, 1, [1, 1, 2, 5, 1], 7], 'DADBADE']
# [12, [0, 1, [1, 1, 2, 5, 1], 7], 'DADBDAE']
# [12, [0, 1, [1, 1, 3, 0, 1], 5], 'ABABE']
# [12, [0, 1, [1, 1, 3, 1, 1], 6], 'ABABDE']
# [12, [0, 1, [1, 1, 3, 1, 1], 6], 'ABADBE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'ABDABE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'ADBABE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'BABDAE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'BADABE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'BADBAE']
# [12, [0, 1, [1, 1, 3, 2, 1], 6], 'DABABE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'ABDABDE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'ADBABDE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'BABDADE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'BADABDE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'BADBADE']
# [12, [0, 1, [1, 1, 3, 3, 1], 7], 'DABABDE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'ABDADBE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'ADBADBE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'BADADBE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'BDABDBE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'DABADBE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'DABDABE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'DADBABE']
# [12, [0, 1, [1, 1, 3, 4, 1], 7], 'DBABDBE']
# [12, [0, 1, [1, 1, 3, 5, 1], 7], 'BDADBDE']
# [12, [0, 1, [1, 1, 3, 5, 1], 7], 'DBADBDE']
# [12, [0, 1, [1, 1, 4, 0, 1], 5], 'BABCE']
# [12, [0, 1, [1, 1, 4, 1, 1], 6], 'BABCDE']
# [12, [0, 1, [1, 1, 4, 1, 1], 6], 'BABDCE']
# [12, [0, 1, [1, 1, 4, 1, 1], 6], 'BADBCE']
# [12, [0, 1, [1, 1, 4, 2, 1], 6], 'BDABCE']
# [12, [0, 1, [1, 1, 4, 2, 1], 6], 'DBABCE']
# [12, [0, 1, [1, 1, 4, 3, 1], 7], 'BDABCDE']
# [12, [0, 1, [1, 1, 4, 3, 1], 7], 'BDABDCE']
# [12, [0, 1, [1, 1, 4, 3, 1], 7], 'DBABCDE']
# [12, [0, 1, [1, 1, 4, 3, 1], 7], 'DBABDCE']
# [12, [0, 1, [1, 1, 4, 4, 1], 7], 'BDADBCE']
# [12, [0, 1, [1, 1, 4, 4, 1], 7], 'DBADBCE']
# [12, [0, 1, [1, 3, 2, 0, 3], 5], 'BECAE']
# [12, [0, 1, [1, 3, 2, 1, 3], 6], 'BECADE']
# [12, [0, 1, [1, 3, 2, 2, 2], 6], 'BEADAE']
# [12, [0, 1, [1, 3, 2, 2, 3], 6], 'BDECAE']
# [12, [0, 1, [1, 3, 2, 2, 3], 6], 'BECDAE']
# [12, [0, 1, [1, 3, 2, 2, 3], 6], 'BEDCAE']
# [12, [0, 1, [1, 3, 2, 2, 3], 6], 'DBECAE']
# [12, [0, 1, [1, 3, 2, 3, 2], 7], 'BEADADE']
# [12, [0, 1, [1, 3, 2, 3, 3], 7], 'BDECADE']
# [12, [0, 1, [1, 3, 2, 3, 3], 7], 'BECDADE']
# [12, [0, 1, [1, 3, 2, 3, 3], 7], 'BEDCADE']
# [12, [0, 1, [1, 3, 2, 3, 3], 7], 'DBECADE']
# [12, [0, 1, [1, 3, 3, 0, 2], 5], 'BEABE']
# [12, [0, 1, [1, 3, 3, 1, 2], 6], 'BEABDE']
# [12, [0, 1, [1, 3, 3, 1, 2], 6], 'BEADBE']
# [12, [0, 1, [1, 3, 3, 2, 2], 6], 'BDEABE']
# [12, [0, 1, [1, 3, 3, 2, 2], 6], 'BEDABE']
# [12, [0, 1, [1, 3, 3, 2, 2], 6], 'DBEABE']
# [12, [0, 1, [1, 3, 3, 3, 2], 7], 'BDEABDE']
# [12, [0, 1, [1, 3, 3, 3, 2], 7], 'BEDABDE']
# [12, [0, 1, [1, 3, 3, 3, 2], 7], 'DBEABDE']
# [12, [0, 1, [1, 3, 3, 4, 2], 7], 'BDEADBE']
# [12, [0, 1, [1, 3, 3, 4, 2], 7], 'BEDADBE']
# [12, [0, 1, [1, 3, 3, 4, 2], 7], 'DBEADBE']
# [12, [0, 1, [1, 4, 2, 0, 3], 5], 'BEACE']
# [12, [0, 1, [1, 4, 2, 1, 3], 6], 'BEADCE']
# [12, [0, 1, [1, 4, 2, 2, 3], 6], 'BDEACE']
# [12, [0, 1, [1, 4, 2, 2, 3], 6], 'BEDACE']
# [12, [0, 1, [1, 4, 2, 2, 3], 6], 'DBEACE']
# [12, [0, 1, [1, 4, 2, 3, 3], 7], 'BDEADCE']
# [12, [0, 1, [1, 4, 2, 3, 3], 7], 'BEDADCE']
# [12, [0, 1, [1, 4, 2, 3, 3], 7], 'DBEADCE']
# [12, [0, 2, [2, 0, 0, 2, 0], 5], 'ADAED']
# [12, [0, 2, [2, 0, 0, 2, 0], 5], 'ADEAD']
# [12, [0, 2, [2, 0, 0, 3, 0], 6], 'ADADED']
# [12, [0, 2, [2, 1, 2, 0, 1], 5], 'AEBAD']
# [12, [0, 2, [2, 1, 2, 2, 1], 6], 'ADEBAD']
# [12, [0, 2, [2, 1, 2, 2, 1], 6], 'DAEBAD']
# [12, [0, 2, [2, 1, 2, 4, 1], 7], 'DADEBAD']
# [12, [0, 2, [2, 2, 1, 0, 2], 5], 'AEBED']
# [12, [0, 2, [2, 2, 1, 0, 3], 5], 'ABECD']
# [12, [0, 2, [2, 2, 1, 1, 2], 6], 'ADEBED']
# [12, [0, 2, [2, 2, 1, 1, 3], 6], 'ABDECD']
# [12, [0, 2, [2, 2, 1, 1, 3], 6], 'ADBECD']
# [12, [0, 2, [2, 2, 1, 2, 2], 6], 'ADABED']
# [12, [0, 2, [2, 2, 1, 2, 2], 6], 'DAEBED']
# [12, [0, 2, [2, 2, 1, 2, 3], 6], 'DABECD']
# [12, [0, 2, [2, 2, 1, 3, 2], 7], 'ADABDED']
# [12, [0, 2, [2, 2, 1, 3, 3], 7], 'DABDECD']
# [12, [0, 2, [2, 2, 1, 4, 2], 7], 'ADADBED']
# [12, [0, 2, [2, 2, 1, 4, 2], 7], 'DABDBED']
# [12, [0, 2, [2, 2, 1, 4, 2], 7], 'DABDEBD']
# [12, [0, 2, [2, 2, 1, 4, 2], 7], 'DADEBED']
# [12, [0, 2, [2, 2, 1, 4, 3], 7], 'DADBECD']
# [12, [0, 2, [2, 2, 1, 5, 2], 7], 'DADBDED']
# [12, [0, 2, [2, 2, 2, 0, 2], 5], 'ABAED']
# [12, [0, 2, [2, 2, 2, 0, 3], 5], 'BAECD']
# [12, [0, 2, [2, 2, 2, 1, 2], 6], 'ABADED']
# [12, [0, 2, [2, 2, 2, 1, 3], 6], 'BADECD']
# [12, [0, 2, [2, 2, 2, 2, 2], 6], 'ABDAED']
# [12, [0, 2, [2, 2, 2, 2, 2], 6], 'ADBAED']
# [12, [0, 2, [2, 2, 2, 2, 2], 6], 'BADAED']
# [12, [0, 2, [2, 2, 2, 2, 2], 6], 'DABAED']
# [12, [0, 2, [2, 2, 2, 2, 3], 6], 'BDAECD']
# [12, [0, 2, [2, 2, 2, 2, 3], 6], 'DBAECD']
# [12, [0, 2, [2, 2, 2, 3, 2], 7], 'ABDADED']
# [12, [0, 2, [2, 2, 2, 3, 2], 7], 'ADBADED']
# [12, [0, 2, [2, 2, 2, 3, 2], 7], 'BADADED']
# [12, [0, 2, [2, 2, 2, 3, 2], 7], 'DABADED']
# [12, [0, 2, [2, 2, 2, 3, 2], 7], 'DABDAED']
# [12, [0, 2, [2, 2, 2, 3, 3], 7], 'BDADECD']
# [12, [0, 2, [2, 2, 2, 3, 3], 7], 'DBADECD']
# [12, [0, 2, [2, 2, 2, 4, 2], 7], 'DADBAED']
# [12, [0, 2, [2, 2, 3, 0, 2], 5], 'BABED']
# [12, [0, 2, [2, 2, 3, 0, 2], 5], 'BAEBD']
# [12, [0, 2, [2, 2, 3, 1, 2], 6], 'BABDED']
# [12, [0, 2, [2, 2, 3, 1, 2], 6], 'BADBED']
# [12, [0, 2, [2, 2, 3, 1, 2], 6], 'BADEBD']
# [12, [0, 2, [2, 2, 3, 2, 2], 6], 'BDABED']
# [12, [0, 2, [2, 2, 3, 2, 2], 6], 'BDAEBD']
# [12, [0, 2, [2, 2, 3, 2, 2], 6], 'DBABED']
# [12, [0, 2, [2, 2, 3, 2, 2], 6], 'DBAEBD']
# [12, [0, 2, [2, 2, 3, 3, 2], 7], 'BDABDED']
# [12, [0, 2, [2, 2, 3, 3, 2], 7], 'DBABDED']
# [12, [0, 2, [2, 2, 3, 4, 2], 7], 'BDADBED']
# [12, [0, 2, [2, 2, 3, 4, 2], 7], 'BDADEBD']
# [12, [0, 2, [2, 2, 3, 4, 2], 7], 'DBADBED']
# [12, [0, 2, [2, 2, 3, 4, 2], 7], 'DBADEBD']
# [12, [0, 2, [2, 2, 5, 0, 2], 6], 'BABCED']
# [12, [0, 2, [2, 2, 5, 1, 2], 7], 'BABCDED']
# [12, [0, 2, [2, 2, 5, 1, 2], 7], 'BABDCED']
# [12, [0, 2, [2, 2, 5, 1, 2], 7], 'BADBCED']
# [12, [0, 2, [2, 2, 5, 2, 2], 7], 'BDABCED']
# [12, [0, 2, [2, 2, 5, 2, 2], 7], 'DBABCED']
# [12, [0, 2, [2, 2, 5, 3, 2], 8], 'BDABCDED']
# [12, [0, 2, [2, 2, 5, 3, 2], 8], 'BDABDCED']
# [12, [0, 2, [2, 2, 5, 3, 2], 8], 'DBABCDED']
# [12, [0, 2, [2, 2, 5, 3, 2], 8], 'DBABDCED']
# [12, [0, 2, [2, 2, 5, 4, 2], 8], 'BDADBCED']
# [12, [0, 2, [2, 2, 5, 4, 2], 8], 'DBADBCED']
# [12, [0, 2, [2, 3, 2, 0, 2], 5], 'ABEAD']
# [12, [0, 2, [2, 3, 2, 0, 2], 5], 'BAEAD']
# [12, [0, 2, [2, 3, 2, 0, 2], 5], 'BEAED']
# [12, [0, 2, [2, 3, 2, 1, 2], 6], 'BEADED']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'ABDEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'ADBEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'BADEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'BDAEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'BDEAED']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'BEDAED']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'DABEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'DBAEAD']
# [12, [0, 2, [2, 3, 2, 2, 2], 6], 'DBEAED']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'BDADEAD']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'BDEADED']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'BEDADED']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'DABDEAD']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'DBADEAD']
# [12, [0, 2, [2, 3, 2, 3, 2], 7], 'DBEADED']
# [12, [0, 2, [2, 3, 2, 4, 2], 7], 'DADBEAD']
# [12, [0, 3, [3, 0, 0, 1, 0], 5], 'ADEDC']
# [12, [0, 3, [3, 0, 0, 2, 0], 5], 'AEDAC']
# [12, [0, 3, [3, 0, 0, 3, 0], 6], 'ADAEDC']
# [12, [0, 3, [3, 0, 0, 3, 0], 6], 'ADEADC']
# [12, [0, 3, [3, 0, 0, 3, 0], 6], 'AEDADC']
# [12, [0, 3, [3, 0, 0, 3, 0], 6], 'DADEDC']
# [12, [0, 3, [3, 1, 1, 1, 1], 6], 'ADEBDC']
# [12, [0, 3, [3, 1, 1, 4, 1], 7], 'DAEBDBC']
# [12, [0, 3, [3, 1, 1, 5, 1], 7], 'DADEBDC']
# [12, [0, 3, [3, 1, 1, 5, 1], 7], 'DAEDBDC']
# [12, [0, 3, [3, 1, 2, 1, 1], 6], 'AEBADC']
# [12, [0, 3, [3, 1, 2, 2, 1], 6], 'AEBDAC']
# [12, [0, 3, [3, 1, 2, 2, 1], 6], 'AEDBAC']
# [12, [0, 3, [3, 1, 2, 3, 1], 7], 'ADEBADC']
# [12, [0, 3, [3, 1, 2, 3, 1], 7], 'AEBDADC']
# [12, [0, 3, [3, 1, 2, 3, 1], 7], 'AEDBADC']
# [12, [0, 3, [3, 1, 2, 3, 1], 7], 'DAEBADC']
# [12, [0, 3, [3, 1, 2, 3, 1], 7], 'DAEBDAC']
# [12, [0, 3, [3, 1, 2, 4, 1], 7], 'DAEDBAC']
# [12, [0, 3, [3, 2, 1, 1, 2], 6], 'ABDEDC']
# [12, [0, 3, [3, 2, 1, 1, 2], 6], 'ADBEDC']
# [12, [0, 3, [3, 2, 1, 1, 2], 6], 'AEBDEC']
# [12, [0, 3, [3, 2, 1, 1, 2], 6], 'AEBEDC']
# [12, [0, 3, [3, 2, 1, 1, 2], 6], 'AEDBEC']
# [12, [0, 3, [3, 2, 1, 1, 3], 6], 'ABECDC']
# [12, [0, 3, [3, 2, 1, 3, 2], 7], 'ADABEDC']
# [12, [0, 3, [3, 2, 1, 3, 2], 7], 'DABDEDC']
# [12, [0, 3, [3, 2, 1, 3, 2], 7], 'DAEBDEC']
# [12, [0, 3, [3, 2, 1, 3, 2], 7], 'DAEBEDC']
# [12, [0, 3, [3, 2, 1, 3, 3], 7], 'DABECDC']
# [12, [0, 3, [3, 2, 1, 4, 2], 7], 'DABEDBC']
# [12, [0, 3, [3, 2, 1, 4, 2], 7], 'DAEDBEC']
# [12, [0, 3, [3, 2, 1, 5, 2], 7], 'DADBEDC']
# [12, [0, 3, [3, 2, 2, 1, 2], 6], 'ABAEDC']
# [12, [0, 3, [3, 2, 2, 1, 2], 6], 'BADEDC']
# [12, [0, 3, [3, 2, 2, 1, 3], 6], 'BAECDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'ABDAEDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'ADBAEDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'BADAEDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'BDADEDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'DABAEDC']
# [12, [0, 3, [3, 2, 2, 3, 2], 7], 'DBADEDC']
# [12, [0, 3, [3, 2, 2, 3, 3], 7], 'BDAECDC']
# [12, [0, 3, [3, 2, 2, 3, 3], 7], 'DBAECDC']
# [12, [0, 3, [3, 2, 3, 1, 2], 6], 'BABEDC']
# [12, [0, 3, [3, 2, 3, 1, 2], 6], 'BAEBDC']
# [12, [0, 3, [3, 2, 3, 1, 2], 6], 'BAEDBC']
# [12, [0, 3, [3, 2, 3, 3, 2], 7], 'BDABEDC']
# [12, [0, 3, [3, 2, 3, 3, 2], 7], 'BDAEBDC']
# [12, [0, 3, [3, 2, 3, 3, 2], 7], 'DBABEDC']
# [12, [0, 3, [3, 2, 3, 3, 2], 7], 'DBAEBDC']
# [12, [0, 3, [3, 2, 3, 4, 2], 7], 'BDAEDBC']
# [12, [0, 3, [3, 2, 3, 4, 2], 7], 'DBAEDBC']
# [12, [0, 3, [3, 2, 5, 1, 2], 7], 'BABCEDC']
# [12, [0, 3, [3, 2, 5, 3, 2], 8], 'BDABCEDC']
# [12, [0, 3, [3, 2, 5, 3, 2], 8], 'DBABCEDC']
# [12, [0, 3, [3, 3, 2, 1, 2], 6], 'ABEADC']
# [12, [0, 3, [3, 3, 2, 1, 2], 6], 'BAEADC']
# [12, [0, 3, [3, 3, 2, 1, 2], 6], 'BEAEDC']
# [12, [0, 3, [3, 3, 2, 2, 2], 6], 'ABEDAC']
# [12, [0, 3, [3, 3, 2, 2, 2], 6], 'BAEDAC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'ABDEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'ABEDADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'ADBEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BADEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BAEDADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BDAEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BDAEDAC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BDEAEDC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'BEDAEDC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'DABEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'DABEDAC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'DBAEADC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'DBAEDAC']
# [12, [0, 3, [3, 3, 2, 3, 2], 7], 'DBEAEDC']
# [12, [0, 4, [4, 0, 0, 1, 0], 5], 'AEDCA']
# [12, [0, 4, [4, 0, 0, 3, 0], 6], 'DAEDCA']
# [12, [0, 4, [4, 1, 1, 1, 1], 6], 'AEBDCA']
# [12, [0, 4, [4, 1, 1, 1, 1], 6], 'AEDBCA']
# [12, [0, 4, [4, 1, 1, 3, 1], 7], 'DAEBDCA']
# [12, [0, 4, [4, 1, 1, 4, 1], 7], 'DAEDBCA']
# [12, [0, 4, [4, 2, 1, 1, 3], 6], 'ABEDCA']
# [11, [3, 2, [5, 3, 2, 2, 3], 7], 'ABEDCAD']
# [12, [0, 4, [4, 2, 1, 3, 3], 7], 'DABEDCA']
# [12, [0, 4, [4, 2, 2, 1, 3], 6], 'BAEDCA']
# [11, [3, 2, [5, 3, 2, 2, 3], 7], 'BAEDCAD']
# [12, [0, 4, [4, 2, 2, 3, 3], 7], 'BDAEDCA']
# [12, [0, 4, [4, 2, 2, 3, 3], 7], 'DBAEDCA']
# [12, [0, 4, [4, 4, 2, 2, 3], 7], 'ABEDACA']
# [12, [0, 4, [4, 4, 2, 2, 3], 7], 'BAEDACA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'ABDEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'ABEDADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'ADBEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BADEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BAEDADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BDAEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BDAEDACA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BDEAEDCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'BEDAEDCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'DABEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'DABEDACA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'DBAEADCA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'DBAEDACA']
# [12, [0, 4, [4, 4, 2, 3, 3], 8], 'DBEAEDCA']
# [12, [1, 0, [2, 0, 0, 2, 0], 5], 'ADAEB']
# [12, [0, 2, [2, 1, 1, 2, 1], 6], 'ADAEBD']
# [12, [0, 3, [3, 1, 1, 3, 1], 7], 'ADAEBDC']
# [12, [1, 0, [2, 0, 0, 2, 0], 5], 'ADEAB']
# [12, [0, 2, [2, 1, 1, 2, 1], 6], 'ADEABD']
# [12, [0, 3, [3, 1, 1, 3, 1], 7], 'ADEABDC']
# [12, [1, 0, [2, 0, 0, 3, 0], 6], 'ADADEB']
# [12, [0, 2, [2, 1, 1, 4, 1], 7], 'ADADEBD']
# [12, [1, 0, [3, 0, 0, 1, 0], 5], 'ADEDB']
# [12, [0, 3, [3, 1, 1, 1, 1], 6], 'ADEDBC']
# [12, [1, 0, [3, 0, 0, 2, 0], 5], 'AEDAB']
# [11, [3, 2, [3, 1, 1, 2, 1], 6], 'AEDABD']
# [12, [0, 3, [3, 1, 1, 2, 1], 6], 'AEDABC']
# [12, [0, 3, [3, 1, 1, 3, 1], 7], 'AEDABDC']
# [12, [1, 0, [3, 0, 0, 3, 0], 6], 'ADAEDB']
# [12, [0, 3, [3, 1, 1, 4, 1], 7], 'ADAEDBC']
# [12, [1, 0, [3, 0, 0, 3, 0], 6], 'ADEADB']
# [12, [0, 3, [3, 1, 1, 4, 1], 7], 'ADEADBC']
# [12, [1, 0, [3, 0, 0, 3, 0], 6], 'AEDADB']
# [12, [0, 3, [3, 1, 1, 4, 1], 7], 'AEDADBC']
# [12, [1, 0, [3, 0, 0, 3, 0], 6], 'DADEDB']
# [12, [0, 3, [3, 1, 1, 4, 1], 7], 'DADEDBC']
# [12, [1, 0, [4, 0, 0, 1, 0], 5], 'AEDCB']
# [12, [0, 4, [4, 1, 1, 1, 1], 6], 'AEDCBA']
# [12, [1, 0, [4, 0, 0, 3, 0], 6], 'DAEDCB']
# [12, [0, 4, [4, 1, 1, 4, 1], 7], 'DAEDCBA']
# [12, [1, 1, [2, 1, 1, 2, 1], 6], 'ADAEBE']
# [12, [1, 1, [2, 1, 1, 2, 1], 6], 'ADEABE']
# [12, [1, 1, [2, 1, 1, 4, 1], 7], 'ADADEBE']
# [12, [1, 1, [2, 1, 2, 0, 1], 5], 'AEBAE']
# [12, [1, 1, [2, 1, 2, 2, 1], 6], 'ADEBAE']
# [12, [1, 1, [2, 1, 2, 2, 1], 6], 'DAEBAE']
# [12, [1, 1, [2, 1, 2, 4, 1], 7], 'DADEBAE']
# [12, [1, 1, [3, 1, 1, 1, 1], 6], 'ADEBDE']
# [12, [1, 1, [3, 1, 1, 1, 1], 6], 'ADEDBE']
# [12, [1, 1, [3, 1, 1, 2, 1], 6], 'AEDABE']
# [12, [1, 1, [3, 1, 1, 3, 1], 7], 'ADAEBDE']
# [12, [1, 1, [3, 1, 1, 3, 1], 7], 'ADEABDE']
# [12, [1, 1, [3, 1, 1, 3, 1], 7], 'AEDABDE']
# [12, [1, 1, [3, 1, 1, 4, 1], 7], 'ADAEDBE']
# [12, [1, 1, [3, 1, 1, 4, 1], 7], 'ADEADBE']
# [12, [1, 1, [3, 1, 1, 4, 1], 7], 'AEDADBE']
# [12, [1, 1, [3, 1, 1, 4, 1], 7], 'DADEDBE']
# [12, [1, 1, [3, 1, 1, 4, 1], 7], 'DAEBDBE']
# [12, [1, 1, [3, 1, 1, 5, 1], 7], 'DADEBDE']
# [12, [1, 1, [3, 1, 1, 5, 1], 7], 'DAEDBDE']
# [12, [1, 1, [3, 1, 2, 1, 1], 6], 'AEBADE']
# [12, [1, 1, [3, 1, 2, 2, 1], 6], 'AEBDAE']
# [12, [1, 1, [3, 1, 2, 2, 1], 6], 'AEDBAE']
# [12, [1, 1, [3, 1, 2, 3, 1], 7], 'ADEBADE']
# [12, [1, 1, [3, 1, 2, 3, 1], 7], 'AEBDADE']
# [12, [1, 1, [3, 1, 2, 3, 1], 7], 'AEDBADE']
# [12, [1, 1, [3, 1, 2, 3, 1], 7], 'DAEBADE']
# [12, [1, 1, [3, 1, 2, 3, 1], 7], 'DAEBDAE']
# [12, [1, 1, [3, 1, 2, 4, 1], 7], 'DAEDBAE']
# [12, [1, 1, [4, 1, 1, 1, 1], 6], 'AEBDCE']
# [12, [1, 1, [4, 1, 1, 1, 1], 6], 'AEDBCE']
# [12, [1, 1, [4, 1, 1, 1, 1], 6], 'AEDCBE']
# [12, [1, 1, [4, 1, 1, 3, 1], 7], 'DAEBDCE']
# [12, [1, 1, [4, 1, 1, 4, 1], 7], 'DAEDBCE']
# [12, [1, 1, [4, 1, 1, 4, 1], 7], 'DAEDCBE']
# [12, [1, 2, [2, 2, 1, 0, 2], 5], 'AEBEA']
# [12, [1, 2, [2, 2, 1, 0, 3], 5], 'ABECA']
# [12, [1, 2, [2, 2, 1, 1, 2], 6], 'ADEBEA']
# [12, [1, 2, [2, 2, 1, 1, 3], 6], 'ABDECA']
# [12, [1, 2, [2, 2, 1, 1, 3], 6], 'ADBECA']
# [12, [1, 2, [2, 2, 1, 2, 2], 6], 'ADABEA']
# [12, [1, 2, [2, 2, 1, 2, 2], 6], 'DAEBEA']
# [12, [1, 2, [2, 2, 1, 2, 3], 6], 'DABECA']
# [12, [1, 2, [2, 2, 1, 3, 2], 7], 'ADABDEA']
# [12, [1, 2, [2, 2, 1, 3, 3], 7], 'DABDECA']
# [12, [1, 2, [2, 2, 1, 4, 2], 7], 'ADADBEA']
# [12, [1, 2, [2, 2, 1, 4, 2], 7], 'DABDBEA']
# [12, [1, 2, [2, 2, 1, 4, 2], 7], 'DABDEBA']
# [12, [1, 2, [2, 2, 1, 4, 2], 7], 'DADEBEA']
# [12, [1, 2, [2, 2, 1, 4, 3], 7], 'DADBECA']
# [12, [1, 2, [2, 2, 1, 5, 2], 7], 'DADBDEA']
# [12, [1, 2, [2, 2, 2, 0, 2], 5], 'ABAEA']
# [12, [1, 2, [2, 2, 2, 0, 3], 5], 'BAECA']
# [12, [1, 2, [2, 2, 2, 1, 2], 6], 'ABADEA']
# [12, [1, 2, [2, 2, 2, 1, 3], 6], 'BADECA']
# [12, [1, 2, [2, 2, 2, 2, 2], 6], 'ABDAEA']
# [12, [1, 2, [2, 2, 2, 2, 2], 6], 'ADBAEA']
# [12, [1, 2, [2, 2, 2, 2, 2], 6], 'BADAEA']
# [12, [1, 2, [2, 2, 2, 2, 2], 6], 'DABAEA']
# [12, [1, 2, [2, 2, 2, 2, 3], 6], 'BDAECA']
# [12, [1, 2, [2, 2, 2, 2, 3], 6], 'DBAECA']
# [12, [1, 2, [2, 2, 2, 3, 2], 7], 'ABDADEA']
# [12, [1, 2, [2, 2, 2, 3, 2], 7], 'ADBADEA']
# [12, [1, 2, [2, 2, 2, 3, 2], 7], 'BADADEA']
# [12, [1, 2, [2, 2, 2, 3, 2], 7], 'DABADEA']
# [12, [1, 2, [2, 2, 2, 3, 2], 7], 'DABDAEA']
# [12, [1, 2, [2, 2, 2, 3, 3], 7], 'BDADECA']
# [12, [1, 2, [2, 2, 2, 3, 3], 7], 'DBADECA']
# [12, [1, 2, [2, 2, 2, 4, 2], 7], 'DADBAEA']
# [12, [1, 2, [2, 2, 3, 0, 2], 5], 'BABEA']
# [12, [1, 2, [2, 2, 3, 0, 2], 5], 'BAEBA']
# [12, [1, 2, [2, 2, 3, 1, 2], 6], 'BABDEA']
# [12, [1, 2, [2, 2, 3, 1, 2], 6], 'BADBEA']
# [12, [1, 2, [2, 2, 3, 1, 2], 6], 'BADEBA']
# [12, [1, 2, [2, 2, 3, 2, 2], 6], 'BDABEA']
# [12, [1, 2, [2, 2, 3, 2, 2], 6], 'BDAEBA']
# [12, [1, 2, [2, 2, 3, 2, 2], 6], 'DBABEA']
# [12, [1, 2, [2, 2, 3, 2, 2], 6], 'DBAEBA']
# [12, [1, 2, [2, 2, 3, 3, 2], 7], 'BDABDEA']
# [12, [1, 2, [2, 2, 3, 3, 2], 7], 'DBABDEA']
# [12, [1, 2, [2, 2, 3, 4, 2], 7], 'BDADBEA']
# [12, [1, 2, [2, 2, 3, 4, 2], 7], 'BDADEBA']
# [12, [1, 2, [2, 2, 3, 4, 2], 7], 'DBADBEA']
# [12, [1, 2, [2, 2, 3, 4, 2], 7], 'DBADEBA']
# [12, [1, 2, [2, 2, 5, 0, 2], 6], 'BABCEA']
# [12, [1, 2, [2, 2, 5, 1, 2], 7], 'BABCDEA']
# [12, [1, 2, [2, 2, 5, 1, 2], 7], 'BABDCEA']
# [12, [1, 2, [2, 2, 5, 1, 2], 7], 'BADBCEA']
# [12, [1, 2, [2, 2, 5, 2, 2], 7], 'BDABCEA']
# [12, [1, 2, [2, 2, 5, 2, 2], 7], 'DBABCEA']
# [12, [1, 2, [2, 2, 5, 3, 2], 8], 'BDABCDEA']
# [12, [1, 2, [2, 2, 5, 3, 2], 8], 'BDABDCEA']
# [12, [1, 2, [2, 2, 5, 3, 2], 8], 'DBABCDEA']
# [12, [1, 2, [2, 2, 5, 3, 2], 8], 'DBABDCEA']
# [12, [1, 2, [2, 2, 5, 4, 2], 8], 'BDADBCEA']
# [12, [1, 2, [2, 2, 5, 4, 2], 8], 'DBADBCEA']
# [12, [1, 2, [3, 2, 1, 1, 2], 6], 'ABDEDA']
# [12, [1, 2, [3, 2, 1, 1, 2], 6], 'ADBEDA']
# [12, [1, 2, [3, 2, 1, 1, 2], 6], 'AEBDEA']
# [12, [1, 2, [3, 2, 1, 1, 2], 6], 'AEBEDA']
# [12, [1, 2, [3, 2, 1, 1, 2], 6], 'AEDBEA']
# [12, [1, 2, [3, 2, 1, 1, 3], 6], 'ABECDA']
# [12, [1, 2, [3, 2, 1, 3, 2], 7], 'ADABEDA']
# [12, [1, 2, [3, 2, 1, 3, 2], 7], 'DABDEDA']
# [12, [1, 2, [3, 2, 1, 3, 2], 7], 'DAEBDEA']
# [12, [1, 2, [3, 2, 1, 3, 2], 7], 'DAEBEDA']
# [12, [1, 2, [3, 2, 1, 3, 3], 7], 'DABECDA']
# [12, [1, 2, [3, 2, 1, 4, 2], 7], 'DABEDBA']
# [12, [1, 2, [3, 2, 1, 4, 2], 7], 'DAEDBEA']
# [12, [1, 2, [3, 2, 1, 5, 2], 7], 'DADBEDA']
# [12, [1, 2, [3, 2, 2, 1, 2], 6], 'ABAEDA']
# [12, [1, 2, [3, 2, 2, 1, 2], 6], 'BADEDA']
# [12, [1, 2, [3, 2, 2, 1, 3], 6], 'BAECDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'ABDAEDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'ADBAEDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'BADAEDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'BDADEDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'DABAEDA']
# [12, [1, 2, [3, 2, 2, 3, 2], 7], 'DBADEDA']
# [12, [1, 2, [3, 2, 2, 3, 3], 7], 'BDAECDA']
# [12, [1, 2, [3, 2, 2, 3, 3], 7], 'DBAECDA']
# [12, [1, 2, [3, 2, 3, 1, 2], 6], 'BABEDA']
# [12, [1, 2, [3, 2, 3, 1, 2], 6], 'BAEBDA']
# [12, [1, 2, [3, 2, 3, 1, 2], 6], 'BAEDBA']
# [12, [1, 2, [3, 2, 3, 3, 2], 7], 'BDABEDA']
# [12, [1, 2, [3, 2, 3, 3, 2], 7], 'BDAEBDA']
# [12, [1, 2, [3, 2, 3, 3, 2], 7], 'DBABEDA']
# [12, [1, 2, [3, 2, 3, 3, 2], 7], 'DBAEBDA']
# [12, [1, 2, [3, 2, 3, 4, 2], 7], 'BDAEDBA']
# [12, [1, 2, [3, 2, 3, 4, 2], 7], 'DBAEDBA']
# [12, [1, 2, [3, 2, 5, 1, 2], 7], 'BABCEDA']
# [12, [1, 2, [3, 2, 5, 3, 2], 8], 'BDABCEDA']
# [12, [1, 2, [3, 2, 5, 3, 2], 8], 'DBABCEDA']
# [12, [1, 3, [1, 3, 2, 0, 3], 5], 'BECAC']
# [12, [1, 3, [1, 3, 2, 1, 3], 6], 'BECADC']
# [12, [1, 3, [1, 3, 2, 2, 2], 6], 'BEADAC']
# [12, [1, 3, [1, 3, 2, 2, 3], 6], 'BDECAC']
# [12, [1, 3, [1, 3, 2, 2, 3], 6], 'BECDAC']
# [12, [1, 3, [1, 3, 2, 2, 3], 6], 'BEDCAC']
# [12, [1, 3, [1, 3, 2, 2, 3], 6], 'DBECAC']
# [12, [1, 3, [1, 3, 2, 3, 2], 7], 'BEADADC']
# [12, [1, 3, [1, 3, 2, 3, 3], 7], 'BDECADC']
# [12, [1, 3, [1, 3, 2, 3, 3], 7], 'BECDADC']
# [12, [1, 3, [1, 3, 2, 3, 3], 7], 'BEDCADC']
# [12, [1, 3, [1, 3, 2, 3, 3], 7], 'DBECADC']
# [12, [1, 3, [1, 3, 3, 0, 2], 5], 'BEABC']
# [12, [1, 3, [1, 3, 3, 1, 2], 6], 'BEABDC']
# [12, [1, 3, [1, 3, 3, 1, 2], 6], 'BEADBC']
# [12, [1, 3, [1, 3, 3, 2, 2], 6], 'BDEABC']
# [12, [1, 3, [1, 3, 3, 2, 2], 6], 'BEDABC']
# [12, [1, 3, [1, 3, 3, 2, 2], 6], 'DBEABC']
# [12, [1, 3, [1, 3, 3, 3, 2], 7], 'BDEABDC']
# [12, [1, 3, [1, 3, 3, 3, 2], 7], 'BEDABDC']
# [12, [1, 3, [1, 3, 3, 3, 2], 7], 'DBEABDC']
# [12, [1, 3, [1, 3, 3, 4, 2], 7], 'BDEADBC']
# [12, [1, 3, [1, 3, 3, 4, 2], 7], 'BEDADBC']
# [12, [1, 3, [1, 3, 3, 4, 2], 7], 'DBEADBC']
# [12, [1, 3, [2, 3, 2, 0, 2], 5], 'ABEAC']
# [12, [1, 3, [2, 3, 2, 0, 2], 5], 'BAEAC']
# [12, [1, 3, [2, 3, 2, 0, 2], 5], 'BEAEC']
# [12, [1, 3, [2, 3, 2, 1, 2], 6], 'BEADEC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'ABDEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'ADBEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'BADEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'BDAEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'BDEAEC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'BEDAEC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'DABEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'DBAEAC']
# [12, [1, 3, [2, 3, 2, 2, 2], 6], 'DBEAEC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'BDADEAC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'BDEADEC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'BEDADEC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'DABDEAC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'DBADEAC']
# [12, [1, 3, [2, 3, 2, 3, 2], 7], 'DBEADEC']
# [12, [1, 3, [2, 3, 2, 4, 2], 7], 'DADBEAC']
# [12, [1, 3, [5, 3, 2, 2, 3], 7], 'ABEDCAC']
# [12, [1, 3, [5, 3, 2, 2, 3], 7], 'BAEDCAC']
# [12, [1, 3, [5, 3, 2, 3, 3], 8], 'ABEDCADC']
# [12, [1, 3, [5, 3, 2, 3, 3], 8], 'BAEDCADC']
# [12, [1, 3, [5, 3, 2, 3, 3], 8], 'BDAEDCAC']
# [12, [1, 3, [5, 3, 2, 3, 3], 8], 'DABEDCAC']
# [12, [1, 3, [5, 3, 2, 3, 3], 8], 'DBAEDCAC']
# [12, [1, 4, [1, 4, 2, 0, 3], 5], 'BEACD']
# [12, [0, 1, [1, 5, 2, 1, 3], 6], 'BEACDE']
# [12, [1, 4, [1, 4, 2, 1, 3], 6], 'BEADCD']
# [12, [1, 4, [1, 4, 2, 2, 3], 6], 'BDEACD']
# [12, [0, 1, [1, 5, 2, 3, 3], 7], 'BDEACDE']
# [12, [1, 4, [1, 4, 2, 2, 3], 6], 'BEDACD']
# [12, [0, 1, [1, 5, 2, 3, 3], 7], 'BEDACDE']
# [12, [1, 4, [1, 4, 2, 2, 3], 6], 'DBEACD']
# [12, [0, 1, [1, 5, 2, 3, 3], 7], 'DBEACDE']
# [12, [1, 4, [1, 4, 2, 3, 3], 7], 'BDEADCD']
# [12, [1, 4, [1, 4, 2, 3, 3], 7], 'BEDADCD']
# [12, [1, 4, [1, 4, 2, 3, 3], 7], 'DBEADCD']
# [12, [2, 1, [1, 1, 1, 4, 1], 7], 'ADABDBA']
# [12, [2, 1, [1, 1, 1, 5, 1], 7], 'ADADBDA']
# [12, [2, 1, [1, 1, 1, 5, 1], 7], 'DABDBDA']
# [12, [2, 1, [2, 1, 1, 2, 1], 6], 'ADAEBA']
# [12, [2, 1, [2, 1, 1, 2, 1], 6], 'ADEABA']
# [12, [2, 1, [2, 1, 1, 4, 1], 7], 'ADADEBA']
# [12, [2, 1, [3, 1, 1, 1, 1], 6], 'ADEBDA']
# [12, [2, 1, [3, 1, 1, 1, 1], 6], 'ADEDBA']
# [12, [2, 1, [3, 1, 1, 2, 1], 6], 'AEDABA']
# [12, [2, 1, [3, 1, 1, 3, 1], 7], 'ADAEBDA']
# [12, [2, 1, [3, 1, 1, 3, 1], 7], 'ADEABDA']
# [12, [2, 1, [3, 1, 1, 3, 1], 7], 'AEDABDA']
# [12, [2, 1, [3, 1, 1, 4, 1], 7], 'ADAEDBA']
# [12, [2, 1, [3, 1, 1, 4, 1], 7], 'ADEADBA']
# [12, [2, 1, [3, 1, 1, 4, 1], 7], 'AEDADBA']
# [12, [2, 1, [3, 1, 1, 4, 1], 7], 'DADEDBA']
# [12, [2, 1, [3, 1, 1, 4, 1], 7], 'DAEBDBA']
# [12, [2, 1, [3, 1, 1, 5, 1], 7], 'DADEBDA']
# [12, [2, 1, [3, 1, 1, 5, 1], 7], 'DAEDBDA']
# [12, [2, 2, [1, 1, 2, 2, 1], 6], 'ABADAB']
# [12, [2, 2, [1, 1, 2, 2, 1], 6], 'ADABAB']
# [12, [2, 2, [1, 1, 2, 3, 1], 7], 'ABADADB']
# [12, [2, 2, [1, 1, 2, 3, 1], 7], 'ADABADB']
# [12, [2, 2, [1, 1, 2, 3, 1], 7], 'ADABDAB']
# [12, [2, 2, [1, 1, 2, 4, 1], 7], 'ADADBAB']
# [12, [2, 2, [1, 1, 2, 4, 1], 7], 'DABDBAB']
# [12, [2, 2, [1, 1, 2, 5, 1], 7], 'DADBADB']
# [12, [2, 2, [1, 1, 2, 5, 1], 7], 'DADBDAB']
# [12, [2, 2, [1, 3, 2, 0, 3], 5], 'BECAB']
# [12, [2, 2, [1, 3, 2, 1, 3], 6], 'BECADB']
# [12, [2, 2, [1, 3, 2, 2, 2], 6], 'BEADAB']
# [12, [2, 2, [1, 3, 2, 2, 3], 6], 'BDECAB']
# [12, [2, 2, [1, 3, 2, 2, 3], 6], 'BECDAB']
# [12, [2, 2, [1, 3, 2, 2, 3], 6], 'BEDCAB']
# [12, [2, 2, [1, 3, 2, 2, 3], 6], 'DBECAB']
# [12, [2, 2, [1, 3, 2, 3, 2], 7], 'BEADADB']
# [12, [2, 2, [1, 3, 2, 3, 3], 7], 'BDECADB']
# [12, [0, 1, [1, 3, 3, 4, 4], 8], 'BDECADBE']
# [12, [1, 3, [1, 3, 3, 4, 4], 8], 'BDECADBC']
# [12, [2, 2, [1, 3, 2, 3, 3], 7], 'BECDADB']
# [12, [0, 1, [1, 3, 3, 4, 4], 8], 'BECDADBE']
# [12, [1, 3, [1, 3, 3, 4, 4], 8], 'BECDADBC']
# [12, [2, 2, [1, 3, 2, 3, 3], 7], 'BEDCADB']
# [12, [0, 1, [1, 3, 3, 4, 4], 8], 'BEDCADBE']
# [12, [1, 3, [1, 3, 3, 4, 4], 8], 'BEDCADBC']
# [12, [2, 2, [1, 3, 2, 3, 3], 7], 'DBECADB']
# [12, [0, 1, [1, 3, 3, 4, 4], 8], 'DBECADBE']
# [12, [1, 3, [1, 3, 3, 4, 4], 8], 'DBECADBC']
# [12, [2, 2, [1, 4, 2, 0, 3], 5], 'BEACB']
# [12, [2, 2, [1, 4, 2, 1, 3], 6], 'BEADCB']
# [12, [2, 2, [1, 4, 2, 2, 3], 6], 'BDEACB']
# [12, [2, 2, [1, 4, 2, 2, 3], 6], 'BEDACB']
# [12, [2, 2, [1, 4, 2, 2, 3], 6], 'DBEACB']
# [12, [2, 2, [1, 4, 2, 3, 3], 7], 'BDEADCB']
# [12, [0, 1, [1, 4, 3, 4, 4], 8], 'BDEADCBE']
# [12, [1, 4, [1, 4, 3, 4, 4], 8], 'BDEADCBD']
# [12, [2, 2, [1, 4, 2, 3, 3], 7], 'BEDADCB']
# [12, [0, 1, [1, 4, 3, 4, 4], 8], 'BEDADCBE']
# [12, [1, 4, [1, 4, 3, 4, 4], 8], 'BEDADCBD']
# [12, [2, 2, [1, 4, 2, 3, 3], 7], 'DBEADCB']
# [12, [0, 1, [1, 4, 3, 4, 4], 8], 'DBEADCBE']
# [12, [1, 4, [1, 4, 3, 4, 4], 8], 'DBEADCBD']
# [12, [2, 2, [1, 5, 2, 1, 3], 6], 'BEACDB']
# [12, [2, 2, [1, 5, 2, 3, 3], 7], 'BDEACDB']
# [12, [0, 1, [1, 5, 3, 4, 4], 8], 'BDEACDBE']
# [12, [2, 2, [1, 5, 2, 3, 3], 7], 'BEDACDB']
# [12, [0, 1, [1, 5, 3, 4, 4], 8], 'BEDACDBE']
# [12, [2, 2, [1, 5, 2, 3, 3], 7], 'DBEACDB']
# [12, [0, 1, [1, 5, 3, 4, 4], 8], 'DBEACDBE']
# [12, [2, 2, [2, 1, 2, 0, 1], 5], 'AEBAB']
# [12, [2, 2, [2, 1, 2, 2, 1], 6], 'ADEBAB']
# [12, [2, 2, [2, 1, 2, 2, 1], 6], 'DAEBAB']
# [12, [2, 2, [2, 1, 2, 4, 1], 7], 'DADEBAB']
# [12, [2, 2, [2, 2, 2, 0, 2], 5], 'ABAEB']
# [12, [2, 2, [2, 2, 2, 0, 3], 5], 'BAECB']
# [12, [2, 2, [2, 2, 2, 1, 2], 6], 'ABADEB']
# [12, [2, 2, [2, 2, 2, 1, 3], 6], 'BADECB']
# [12, [2, 2, [2, 2, 2, 2, 2], 6], 'ABDAEB']
# [12, [2, 2, [2, 2, 2, 2, 2], 6], 'ADBAEB']
# [12, [2, 2, [2, 2, 2, 2, 2], 6], 'BADAEB']
# [12, [2, 2, [2, 2, 2, 2, 2], 6], 'DABAEB']
# [12, [2, 2, [2, 2, 2, 2, 3], 6], 'BDAECB']
# [12, [2, 2, [2, 2, 2, 2, 3], 6], 'DBAECB']
# [12, [2, 2, [2, 2, 2, 3, 2], 7], 'ABDADEB']
# [12, [2, 2, [2, 2, 2, 3, 2], 7], 'ADBADEB']
# [12, [2, 2, [2, 2, 2, 3, 2], 7], 'BADADEB']
# [12, [2, 2, [2, 2, 2, 3, 2], 7], 'DABADEB']
# [12, [2, 2, [2, 2, 2, 3, 2], 7], 'DABDAEB']
# [12, [2, 2, [2, 2, 2, 3, 3], 7], 'BDADECB']
# [12, [0, 2, [2, 2, 3, 4, 4], 8], 'BDADECBD']
# [12, [1, 2, [2, 2, 3, 4, 4], 8], 'BDADECBA']
# [12, [2, 2, [2, 2, 2, 3, 3], 7], 'DBADECB']
# [12, [0, 2, [2, 2, 3, 4, 4], 8], 'DBADECBD']
# [12, [1, 2, [2, 2, 3, 4, 4], 8], 'DBADECBA']
# [12, [2, 2, [2, 2, 2, 4, 2], 7], 'DADBAEB']
# [12, [2, 2, [2, 3, 2, 0, 2], 5], 'ABEAB']
# [12, [2, 2, [2, 3, 2, 0, 2], 5], 'BAEAB']
# [12, [2, 2, [2, 3, 2, 0, 2], 5], 'BEAEB']
# [12, [2, 2, [2, 3, 2, 1, 2], 6], 'BEADEB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'ABDEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'ADBEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'BADEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'BDAEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'BDEAEB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'BEDAEB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'DABEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'DBAEAB']
# [12, [2, 2, [2, 3, 2, 2, 2], 6], 'DBEAEB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'BDADEAB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'BDEADEB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'BEDADEB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'DABDEAB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'DBADEAB']
# [12, [2, 2, [2, 3, 2, 3, 2], 7], 'DBEADEB']
# [12, [2, 2, [2, 3, 2, 4, 2], 7], 'DADBEAB']
# [12, [2, 2, [3, 1, 2, 1, 1], 6], 'AEBADB']
# [12, [2, 2, [3, 1, 2, 2, 1], 6], 'AEBDAB']
# [12, [2, 2, [3, 1, 2, 2, 1], 6], 'AEDBAB']
# [12, [2, 2, [3, 1, 2, 3, 1], 7], 'ADEBADB']
# [12, [2, 2, [3, 1, 2, 3, 1], 7], 'AEBDADB']
# [12, [2, 2, [3, 1, 2, 3, 1], 7], 'AEDBADB']
# [12, [2, 2, [3, 1, 2, 3, 1], 7], 'DAEBADB']
# [12, [2, 2, [3, 1, 2, 3, 1], 7], 'DAEBDAB']
# [12, [2, 2, [3, 1, 2, 4, 1], 7], 'DAEDBAB']
# [12, [2, 2, [3, 2, 2, 1, 2], 6], 'ABAEDB']
# [12, [2, 2, [3, 2, 2, 1, 2], 6], 'BADEDB']
# [12, [2, 2, [3, 2, 2, 1, 3], 6], 'BAECDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'ABDAEDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'ADBAEDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'BADAEDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'BDADEDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'DABAEDB']
# [12, [2, 2, [3, 2, 2, 3, 2], 7], 'DBADEDB']
# [12, [2, 2, [3, 2, 2, 3, 3], 7], 'BDAECDB']
# [12, [0, 3, [3, 2, 3, 4, 4], 8], 'BDAECDBC']
# [12, [1, 2, [3, 2, 3, 4, 4], 8], 'BDAECDBA']
# [12, [2, 2, [3, 2, 2, 3, 3], 7], 'DBAECDB']
# [12, [0, 3, [3, 2, 3, 4, 4], 8], 'DBAECDBC']
# [12, [1, 2, [3, 2, 3, 4, 4], 8], 'DBAECDBA']
# [12, [2, 2, [3, 3, 2, 1, 2], 6], 'ABEADB']
# [12, [2, 2, [3, 3, 2, 1, 2], 6], 'BAEADB']
# [12, [2, 2, [3, 3, 2, 1, 2], 6], 'BEAEDB']
# [12, [2, 2, [3, 3, 2, 2, 2], 6], 'ABEDAB']
# [12, [2, 2, [3, 3, 2, 2, 2], 6], 'BAEDAB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'ABDEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'ABEDADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'ADBEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BADEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BAEDADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BDAEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BDAEDAB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BDEAEDB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'BEDAEDB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'DABEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'DABEDAB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'DBAEADB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'DBAEDAB']
# [12, [2, 2, [3, 3, 2, 3, 2], 7], 'DBEAEDB']
# [12, [2, 2, [4, 2, 2, 1, 3], 6], 'BAEDCB']
# [12, [2, 2, [4, 2, 2, 3, 3], 7], 'BDAEDCB']
# [12, [0, 4, [4, 2, 3, 4, 4], 8], 'BDAEDCBA']
# [12, [1, 3, [5, 3, 3, 4, 4], 9], 'BDAEDCBAC']
# [11, [2, 4, [5, 4, 4, 4, 4], 10], 'BDAEDCBACE']
# [12, [1, 4, [5, 4, 4, 4, 4], 10], 'BDAEDCBACD']
# [11, [2, 4, [5, 5, 4, 5, 5], 11], 'BDAEDCBACDE']

# %%
curr_char = {}
print(curr_char.get('A') == None)
# Out:
# True

# %%
char_dic = {}
char_dic[1] = len(char_dic)
char_dic[1]
# Out:
# 0

# %%
char_dic["A1"]
# Out:
# 1

# %%
# Out:
# 65
# 66

# %%
h[2][4]
# Out:
# 2
